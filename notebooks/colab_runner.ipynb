# %% [markdown]
# # GradeEye Colab Runner
# Upload your project zip file to this Colab session (e.g. `gradeeye.zip`), then run the cells below.

# %%
# !unzip -q gradeeye.zip -d gradeeye
# %cd gradeeye
# !pip install -r requirements.txt

# %%
# Kaggle Setup (make sure you upload kaggle.json!)
# !mkdir -p ~/.kaggle
# !cp ../kaggle.json ~/.kaggle/ || echo 'Please upload kaggle.json to the root folder first!'
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !python scripts/download_datasets.py --dataset all
# !python scripts/build_manifests.py --dataset all
# !python scripts/preprocess_all.py
# !python scripts/compute_norm_stats.py --dataset all

# %%
# Train
# !python scripts/train.py --config configs/full_method.yaml

# %%
# Resume (Optional)
# !python scripts/train.py --config configs/full_method.yaml --resume saved/checkpoints/run_stepX.pt
